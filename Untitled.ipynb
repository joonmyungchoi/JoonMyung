# %%
import torch
import os

# 0.Setting
# Section A. View Point
from joonmyung.draw import drawImgPlot
from playground.analysis.dataset import JDataset
from playground.analysis.model import JModel

view = [True, False, False, True, True] # [Image, Attention, Rollout, GradCam, What I Want]
save_path, save = '/hub_data/joonmyung/conference/playgrounds/results/', False

# Section B. Data
root_path, dataset = "/hub_data/joonmyung/data", "imagenet"
data_num = [[0, 0], [1, 0], [2, 0], [3, 0], [0, 1], [1, 1], [2, 1], [3, 1]]
B = len(data_num)
lam = 0.6
num_classes = 1000 if dataset == "imagenet" else 100

# Section C. Condition
es = []
# ls = [0, 2, 4, 6]
les = [-3, -1]
query_num = 15
columns = 4

# Section D. HeatMap Condition
fmt, border, cbar    = 0, True, False

# model_name = "PATCH"
device_type = 'cuda'
device = torch.device(device_type)

# 2. Load Data
dataset = JDataset(root_path, dataset, device)
samples, targets, imgs, label_names = dataset.getitems(data_num)
label_names.insert(0, f"{label_names[0]} : {lam} + {label_names[1]} : {1 - lam}")
label_names.insert(0, f"{label_names[0]} : {1-lam} + {label_names[1]} : {lam}")
if view[0]:
    drawImgPlot(dataset.unNormalize(samples), columns = label_names, col=len(samples))


model_name, model_path = "DEIT", "/hub_data/joonmyung/conference/2023ICCV/1.3.2/OURS:T:01/checkpoint_{}.pth"
model_number, ana_type, epoch = 1, "2023ICCV", 0

print("file list : ", os.listdir("/" + os.path.join(*model_path.split("/")[:-1])))

modelMaker = JModel(model_name, num_classes, model_path, model_number=model_number, ana_type = ana_type, device=device)
# Out:
# No handles with labels found to put in legend.
# file list :  ['args.py', 'checkpoint_120.pth', 'checkpoint_20.pth', 'checkpoint_40.pth', 'checkpoint_100.pth', 'checkpoint_80.pth', 'log.txt', 'checkpoint.pth', 'checkpoint_60.pth', 'checkpoint_0.pth']

# %%
es = [0, 20,40, 60, 80, 100, 120]
for e in es:
    model = modelMaker.getModel(e)[0]
    model.eval()
    outputs, output_12, loss_mask, loss_mae_1, loss_mae_2, mask_acc, mae_target, mae_target_mixed, mae_pred_1, mae_pred_2, indices, lam = model(samples)
    drawImgPlot(torch.stack([mae_target, mae_target_mixed, mae_target[indices], mae_pred_1, mae_pred_2], dim=1).reshape(-1, 3, 224, 224)[5:10], col=5);
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-236239e14297>", line 5, in <module>
#     outputs, output_12, loss_mask, loss_mae_1, loss_mae_2, mask_acc, mae_target, mae_target_mixed, mae_pred_1, mae_pred_2, indices, lam = model(samples)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/home/joonmyung/project/JoonMyung/playground/analysis/models/mae_trans/deit.py", line 414, in forward
#     cls_token, loss_mask, loss_mae_1, loss_mae_2, mask_acc, mae_target, mae_pred_1, mae_pred_2 = self.forward_loss(imgs, pred, mask_a, mask, attn, cls_token, indices)
#   File "/home/joonmyung/project/JoonMyung/playground/analysis/models/mae_trans/deit.py", line 363, in forward_loss
#     ab_match = ((1 - mask_1 ^ mask_pred_a).sum(dim=[1, 2]) > (self.num_patches // 2)).type(torch.int64).reshape(-1, 1, 1) # (128, 1, 1)
# TypeError: unsupported operand type(s) for -: 'int' and 'NoneType'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# Traceback (most recent call last):
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-236239e14297>", line 5, in <module>
#     outputs, output_12, loss_mask, loss_mae_1, loss_mae_2, mask_acc, mae_target, mae_target_mixed, mae_pred_1, mae_pred_2, indices, lam = model(samples)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/home/joonmyung/project/JoonMyung/playground/analysis/models/mae_trans/deit.py", line 414, in forward
#     cls_token, loss_mask, loss_mae_1, loss_mae_2, mask_acc, mae_target, mae_pred_1, mae_pred_2 = self.forward_loss(imgs, pred, mask_a, mask, attn, cls_token, indices)
#   File "/home/joonmyung/project/JoonMyung/playground/analysis/models/mae_trans/deit.py", line 363, in forward_loss
#     ab_match = ((1 - mask_1 ^ mask_pred_a).sum(dim=[1, 2]) > (self.num_patches // 2)).type(torch.int64).reshape(-1, 1, 1) # (128, 1, 1)
# TypeError: unsupported operand type(s) for -: 'int' and 'NoneType'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# Traceback (most recent call last):
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-236239e14297>", line 5, in <module>
#     outputs, output_12, loss_mask, loss_mae_1, loss_mae_2, mask_acc, mae_target, mae_target_mixed, mae_pred_1, mae_pred_2, indices, lam = model(samples)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/home/joonmyung/project/JoonMyung/playground/analysis/models/mae_trans/deit.py", line 414, in forward
#     cls_token, loss_mask, loss_mae_1, loss_mae_2, mask_acc, mae_target, mae_pred_1, mae_pred_2 = self.forward_loss(imgs, pred, mask_a, mask, attn, cls_token, indices)
#   File "/home/joonmyung/project/JoonMyung/playground/analysis/models/mae_trans/deit.py", line 363, in forward_loss
#     ab_match = ((1 - mask_1 ^ mask_pred_a).sum(dim=[1, 2]) > (self.num_patches // 2)).type(torch.int64).reshape(-1, 1, 1) # (128, 1, 1)
# TypeError: unsupported operand type(s) for -: 'int' and 'NoneType'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3282, in run_ast_nodes
#     self.showtraceback()
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1211, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/home/joonmyung/.conda/envs/2023ICCV_MIXUP/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
